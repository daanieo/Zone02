# %% [markdown]
# Data analysis for GAMA's zone02 output

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("result.txt",sep=",",skiprows=1,header=None)
data = data.drop(columns=[0,3,1443])
data.head(10)
# Out:
#    1     2     4     5     6     7     8     9     10    11    ...  1433  \
# 0    10     0   200   200   200   200   200   200   200   200  ...  7380
# 1    10     0   182   182   182   182   182   182   182   182  ...  7115
# 2    10     0   201   201   201   201   201   201   201   201  ...  7742
# 3    10     0   188   188   188   188   188   188   188   188  ...  7514
# 4    10     1   296   296   296   296   296   296   296   296  ...   562
# 5    10     1   276   276   276   276   276   276   276   276  ...   485
# 6    10     1   301   301   301   301   301   301   301   301  ...   589
# 7    10     1   304   304   304   304   304   304   304   304  ...   564
# 8    10     2   383   383   383   383   383   383   383   383  ...  1133
# 9    10     2   357   357   357   357   357   357   357   357  ...   977
#
#    1434  1435  1436  1437  1438  1439  1440  1441  1442
# 0  7380  7380  7380  7380  7380  7380  7380  7380  7380
# ...

# %%
for i in range(len(data)):
    plt.plot(data.iloc[i,:])

plt.title("Filling up the model")
plt.ylabel("hungry days")
plt.xlabel("ticks")
plt.ylim([0,8500])
plt.xlim([0,1450])
# Out:
# (0.0, 1450.0)
